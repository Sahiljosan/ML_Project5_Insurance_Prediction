# %%
import pandas as pd
import json

# %%
df = pd.read_csv(r"G:\Udemy\DATA SCIENCE ineuron\VS Code\ML_Project5_Insurance_Prediction\insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
json_record = list(json.loads(df.T.to_json()).values())

# %%
json_record
# Out:
# [{'age': 19,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 16884.92},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 33.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1725.55},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4449.46},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 22.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 21984.47},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3866.86},
#  {'age': 31,
#   'sex': 'female',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3756.62},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 33.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
# ...
